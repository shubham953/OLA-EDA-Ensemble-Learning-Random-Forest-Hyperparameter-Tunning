# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham953/OLA-EDA-Ensemble-Learning-Random-Forest-Hyperparameter-Tunning/blob/main/Untitled181.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **OLA - Ensemble Learning**

# %% [markdown]
# Recruiting and retaining drivers is seen by industry watchers as a tough battle for Ola. Churn among drivers is high and it’s very easy for drivers to stop working for the service on the fly or jump to Uber depending on the rates.
#
# As the companies get bigger, the high churn could become a bigger problem. To find new drivers, Ola is casting a wide net, including people who don’t have cars for jobs. But this acquisition is really costly. Losing drivers frequently impacts the morale of the organization and acquiring new drivers is more expensive than retaining existing ones.
#
# You are working as a data scientist with the Analytics Department of Ola, focused on driver team attrition. You are provided with the monthly information for a segment of drivers for 2019 and 2020 and tasked to predict whether a driver will be leaving the company or not based on their attributes like
#
# Demographics (city, age, gender etc.)
# Tenure information (joining date, Last Date)
# Historical data regarding the performance of the driver (Quarterly rating, Monthly business acquired, grade, Income)
#
# Column Profiling:
#
# MMMM-YY : Reporting Date (Monthly)
#
#
# Driver_ID : Unique id for drivers
#
# Age : Age of the driver
#
# Gender : Gender of the driver – Male : 0, Female: 1
#
# City : City Code of the driver
#
# Education_Level : Education level – 0 for 10+ ,1 for 12+ ,2 for graduate
#
# Income : Monthly average Income of the driver
#
# Date Of Joining : Joining date for the driver
#
# LastWorkingDate : Last date of working for the driver
#
# Joining Designation : Designation of the driver at the time of joining
#
# Grade : Grade of the driver at the time of reporting
#
# Total Business Value : The total business value acquired by the driver in a
# month (negative business indicates cancellation/refund or car EMI adjustments)
#
# Quarterly Rating : Quarterly rating of the driver: 1,2,3,4,5 (higher is better)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("ola_driver_scaler.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    MMM-YY  Driver_ID   Age  Gender City  Education_Level  \
# 0           0  01/01/19          1  28.0     0.0  C23                2
# 1           1  02/01/19          1  28.0     0.0  C23                2
# 2           2  03/01/19          1  28.0     0.0  C23                2
# 3           3  11/01/20          2  31.0     0.0   C7                2
# 4           4  12/01/20          2  31.0     0.0   C7                2
#
#    Income Dateofjoining LastWorkingDate  Joining Designation  Grade  \
# 0   57387      24/12/18             NaN                    1      1
# 1   57387      24/12/18             NaN                    1      1
# 2   57387      24/12/18        03/11/19                    1      1
# 3   67016      11/06/20             NaN                    2      2
# 4   67016      11/06/20             NaN                    2      2
#
#    Total Business Value  Quarterly Rating
# 0               2381060                 2
# 1               -665480                 2
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19104 entries, 0 to 19103
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MMM-YY                19104 non-null  object
#  1   Driver_ID             19104 non-null  int64
#  2   Age                   19043 non-null  float64
#  3   Gender                19052 non-null  float64
#  4   City                  19104 non-null  object
#  5   Education_Level       19104 non-null  int64
#  6   Income                19104 non-null  int64
#  7   Dateofjoining         19104 non-null  object
#  8   LastWorkingDate       1616 non-null   object
#  9   Joining Designation   19104 non-null  int64
#  10  Grade                 19104 non-null  int64
#  11  Total Business Value  19104 non-null  int64
#  12  Quarterly Rating      19104 non-null  int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 1.9+ MB

# %%
df=df.rename(columns={"LastWorkingDate":"Churned"})

# %%
df
# Out:
#          MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income  \
# 0      01/01/19          1  28.0     0.0  C23                2   57387
# 1      02/01/19          1  28.0     0.0  C23                2   57387
# 2      03/01/19          1  28.0     0.0  C23                2   57387
# 3      11/01/20          2  31.0     0.0   C7                2   67016
# 4      12/01/20          2  31.0     0.0   C7                2   67016
# ...         ...        ...   ...     ...  ...              ...     ...
# 19099  08/01/20       2788  30.0     0.0  C27                2   70254
# 19100  09/01/20       2788  30.0     0.0  C27                2   70254
# 19101  10/01/20       2788  30.0     0.0  C27                2   70254
# 19102  11/01/20       2788  30.0     0.0  C27                2   70254
# 19103  12/01/20       2788  30.0     0.0  C27                2   70254
#
#       Dateofjoining   Churned  Joining Designation  Grade  \
# ...

# %%
df["Churned"]=df["Churned"].fillna(0)

# %%
df.loc[df["Churned"]!=0,"Churned"] = 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19104 entries, 0 to 19103
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MMM-YY                19104 non-null  object
#  1   Driver_ID             19104 non-null  int64
#  2   Age                   19043 non-null  float64
#  3   Gender                19052 non-null  float64
#  4   City                  19104 non-null  object
#  5   Education_Level       19104 non-null  int64
#  6   Income                19104 non-null  int64
#  7   Dateofjoining         19104 non-null  object
#  8   Churned               19104 non-null  object
#  9   Joining Designation   19104 non-null  int64
#  10  Grade                 19104 non-null  int64
#  11  Total Business Value  19104 non-null  int64
#  12  Quarterly Rating      19104 non-null  int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 1.9+ MB

# %%
df
# Out:
#          MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income  \
# 0      01/01/19          1  28.0     0.0  C23                2   57387
# 1      02/01/19          1  28.0     0.0  C23                2   57387
# 2      03/01/19          1  28.0     0.0  C23                2   57387
# 3      11/01/20          2  31.0     0.0   C7                2   67016
# 4      12/01/20          2  31.0     0.0   C7                2   67016
# ...         ...        ...   ...     ...  ...              ...     ...
# 19099  08/01/20       2788  30.0     0.0  C27                2   70254
# 19100  09/01/20       2788  30.0     0.0  C27                2   70254
# 19101  10/01/20       2788  30.0     0.0  C27                2   70254
# 19102  11/01/20       2788  30.0     0.0  C27                2   70254
# 19103  12/01/20       2788  30.0     0.0  C27                2   70254
#
#       Dateofjoining Churned  Joining Designation  Grade  Total Business Value  \
# ...

# %%
fig=plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.countplot(x=df["Churned"])
plt.subplot(1,2,2)
plot=sns.countplot(x=df["Churned"],hue=df["Gender"])

# %%
gc=df["Gender"].value_counts()

# %%
gc
# Out:
# 0.0    11074
# 1.0     7978
# Name: Gender, dtype: int64

# %%
df.loc[(df["Gender"]==1.0) & (df["Churned"]==1)]
# Out:
#          MMM-YY  Driver_ID   Age  Gender City  Education_Level  Income  \
# 55     02/01/19         16  30.0     1.0  C23                0   52963
# 67     05/01/19         18  27.0     1.0  C17                1   31631
# 73     03/01/20         20  26.0     1.0  C19                0   40342
# 87     02/01/20         21  34.0     1.0  C29                1   22755
# 179    11/01/20         34  28.0     1.0  C14                1   65813
# ...         ...        ...   ...     ...  ...              ...     ...
# 18984  06/01/19       2768  30.0     1.0   C1                2   80138
# 19014  05/01/19       2772  23.0     1.0  C26                0   51670
# 19036  04/01/19       2776  27.0     1.0  C27                1   54397
# 19081  10/01/20       2785  34.0     1.0   C9                0   12105
# 19096  06/01/19       2787  28.0     1.0  C20                2   69498
#
#       Dateofjoining Churned  Joining Designation  Grade  Total Business Value  \
# ...

# %%
665/7954
# Out:
# 0.08360573296454614

# %%
plot=sns.countplot(x=df["Churned"],hue=df["Gender"])
i=0
for p in plot.patches:

  x=p.get_x()
  y=p.get_y()+p.get_height()
  if(p.get_height()==0):continue
  if(i==0 or i==1):
    plot.annotate(np.round((100*p.get_height()/gc[0])),(x,y))
  else:

    plot.annotate(np.round((100*p.get_height()/gc[1]),2),(x,y))
  if(i==5):break
  print(p,i)
  i +=1

plt.xlabel("Churned-Percentage")
plt.show()
# Out:
# Rectangle(xy=(-0.4, 0), width=0.4, height=10130, angle=0) 0
# Rectangle(xy=(0.6, 0), width=0.4, height=944, angle=0) 1
# Rectangle(xy=(5.55112e-17, 0), width=0.4, height=7311, angle=0) 2
# Rectangle(xy=(1, 0), width=0.4, height=667, angle=0) 3

# %%
fig=plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.countplot(x=df["Churned"],hue=df["Quarterly Rating"])
plt.subplot(1,2,2)
plot=sns.countplot(x=df["Churned"],hue=df["Grade"])

# %%
sns.histplot(x=df["Age"],bins=[0,5,10,15,20,25,30,35],hue=df["Churned"])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(x=df["Income"])
# Out:
# <Axes: xlabel='Income'>

# %%
sns.histplot(x=df["Income"],bins=[0,25000,50000,75000,100000,125000,150000,200000,250000],hue=df["Churned"])
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
fig = plt.figure(figsize=(100,15))
plt.subplot(1,2,2)
plot=sns.countplot(x=df["Churned"],hue=df["City"])
plt.xticks(rotation=45)
# Out:
# ([0, 1], [Text(0, 0, '0'), Text(1, 0, '1')])

# %%
df["Churned"]=df["Churned"].astype("int")
df.drop(columns=['MMM-YY','Dateofjoining','City'],inplace=True)
y=df['Churned']
df.drop(columns=['Churned'],axis=1,inplace=True)

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer()
df = imputer.fit_transform(df)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df)

# %%
x
# Out:
# array([[-1.74493508, -1.06567791, -0.84969899, ..., -1.22034792,
#          1.60367428, -0.00881225],
#        [-1.74493508, -1.06567791, -0.84969899, ..., -1.22034792,
#         -1.09648237, -0.00881225],
#        [-1.74493508, -1.06567791, -0.84969899, ..., -1.22034792,
#         -0.50666564, -0.00881225],
#        ...,
#        [ 1.69290216, -0.7458138 , -0.84969899, ..., -0.24615016,
#         -0.50666564, -0.00881225],
#        [ 1.69290216, -0.7458138 , -0.84969899, ..., -0.24615016,
#         -0.32903286, -0.00881225],
#        [ 1.69290216, -0.7458138 , -0.84969899, ..., -0.24615016,
#         -0.14196981, -0.00881225]])

# %%
y.value_counts()
# Out:
# 0    17488
# 1     1616
# Name: Churned, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,precision_score,f1_score,roc_curve,auc
from imblearn.over_sampling import ADASYN
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
A=ADASYN()
x,y=A.fit_resample(x,y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
y.value_counts()
# Out:
# 1    17746
# 0    17488
# Name: Churned, dtype: int64

# %%
RFC=RandomForestClassifier(n_estimators=150,max_depth=30)
model=RFC.fit(x_train,y_train)

# %%
y_predict=model.predict(x_test)

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[4701,  490],
#        [ 464, 4916]])

# %%
f1_score(y_test, y_predict)
# Out:
# 0.9115520118672353

# %%
param_grid={
    'n_estimators' :[30,70,120,200],
    'max_depth' :[10,30,50,70]

}

# %%
rfc_h = GridSearchCV(model, param_grid, cv=5)

# %%
rfc_h.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(max_depth=30, n_estimators=150),
#              param_grid={'max_depth': [10, 30, 50, 70],
#                          'n_estimators': [30, 70, 120, 200]})

# %%
print("Tuned Logistic Regression Parameters: {}".format(rfc_h.best_params_))
print("Best score is {}".format(rfc_h.best_score_))
# Out:
# Tuned Logistic Regression Parameters: {'max_depth': 70, 'n_estimators': 120}
# Best score is 0.9060538877076096

# %%
 RFC=RandomForestClassifier(n_estimators=120,max_depth=70)
model=RFC.fit(x_train,y_train)

# %%
y_predict=model.predict(x_test)

# %%
cfc_report=classification_report(y_test,y_predict)

# %%
print(cfc_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91      5191
#            1       0.92      0.91      0.91      5380
#
#     accuracy                           0.91     10571
#    macro avg       0.91      0.91      0.91     10571
# weighted avg       0.91      0.91      0.91     10571
